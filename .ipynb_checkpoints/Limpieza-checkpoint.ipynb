# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
attacks = pd.read_csv("data/attacks.csv",encoding = "ISO-8859-1")

# %%
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
lista = attacks["Country"]

# %%
lista
# Out:
# 0              USA
# 1              USA
# 2              USA
# 3        AUSTRALIA
# 4           MEXICO
#            ...
# 25718          NaN
# 25719          NaN
# 25720          NaN
# 25721          NaN
# 25722          NaN
# Name: Country, Length: 25723, dtype: object

# %%
pd.isnull(lista)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25718     True
# 25719     True
# 25720     True
# 25721     True
# 25722     True
# Name: Country, Length: 25723, dtype: bool

# %%
pd.isnull(lista).sum() #Con esto obtenemos la cantidad de valores Nan que contiene nuestra columna
# Out:
# 19471

# %%
#El siguiente paso sería proceder a limpiarlos para poder extraer los datos que queremos.

# %%
attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
attacks.Country.unique()#Aquí podemos visualizar la lista de países donde se han producido ataques de tiburones
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
paises = attacks.Country.value_counts().head(10) #Así odemos visualizar cuales son los paises que han sufrido mas ataques.

# %%
paises
# Out:
# USA                 2229
# AUSTRALIA           1338
# SOUTH AFRICA         579
# PAPUA NEW GUINEA     134
# NEW ZEALAND          128
# BRAZIL               112
# BAHAMAS              109
# MEXICO                89
# ITALY                 71
# FIJI                  62
# Name: Country, dtype: int64

# %%
paises2 = pd.DataFrame(paises) 
paises2
#Ahora tenemos los datos limpios y visualizar en tabla los 10 paises que mas ataques han recibido hasta el momento.
# Out:
#                   Country
# USA                  2229
# AUSTRALIA            1338
# SOUTH AFRICA          579
# PAPUA NEW GUINEA      134
# NEW ZEALAND           128
# BRAZIL                112
# BAHAMAS               109
# MEXICO                 89
# ITALY                  71
# FIJI                   62

# %%
paises2.sum() #Entre los 20 primeros paises, suman un total de 5306 ataques recibidos por tiurón.
# Out:
# Country    4851
# dtype: int64

# %%
#Hay que ponerle nombre a las columnas para que quede bien estructurado

# %%
data = [['USA','2229'],['AUSTRALIA','1338'],['SOUTH AFRICA','579'],['PAPUA NEW GUINEA','134'],['NEW ZEALAND','128'],['BRAZIL','112'],['BAHAMAS','109'],['MEXICO','89'],['ITALY','71'],['FIJI','62']]
df = pd.DataFrame(data,columns=['Pais','AtaquesRecibidos'])
print(df)
# Out:
#                Pais AtaquesRecibidos
# 0               USA             2229
# 1         AUSTRALIA             1338
# 2      SOUTH AFRICA              579
# 3  PAPUA NEW GUINEA              134
# 4       NEW ZEALAND              128
# 5            BRAZIL              112
# 6           BAHAMAS              109
# 7            MEXICO               89
# 8             ITALY               71
# 9              FIJI               62

# %%
pd.DataFrame(df)
#Ya por fin tenemos los datos divididos en sus correspondientes columnas.
# Out:
#                Pais AtaquesRecibidos
# 0               USA             2229
# 1         AUSTRALIA             1338
# 2      SOUTH AFRICA              579
# 3  PAPUA NEW GUINEA              134
# 4       NEW ZEALAND              128
# 5            BRAZIL              112
# 6           BAHAMAS              109
# 7            MEXICO               89
# 8             ITALY               71
# 9              FIJI               62

# %%
df.to_csv("data/tabla.csv")
